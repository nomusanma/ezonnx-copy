# %%
from ezonnx import RTMW3D,visualize_images
pose = RTMW3D()
ret = pose("/Users/satoshi/python/ezonnx/examples/images/surf.jpg")
# Out:
# /Users/satoshi/python/ezonnx/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:982: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(

# %%
visualize_images("Result",ret.visualized_img)

# %%
kpts_yz  = ret.kpts[...,1:]
import matplotlib.pyplot as plt
plt.scatter(kpts_yz[0,:,1],kpts_yz[0,:,0])
plt.gca().invert_yaxis()
plt.show()
