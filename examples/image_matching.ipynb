# %% [markdown]
# ### ALIKED - LightGlue

# %%
from ezonnx import ALIKEDLightGlue, visualize_images
matcher = ALIKEDLightGlue("16rot-top1k")
res = matcher('images/cathe0.jpg','images/cathe1.jpg')
visualize_images("Matching Result", res.visualized_img)

# %%
res.m_kpts0.shape, res.m_kpts1.shape, res.scores.shape
# Out:
# ((469, 2), (469, 2), (469,))

# %% [markdown]
# ### ALIKED - local feature detection & description

# %%
from ezonnx import ALIKED, visualize_images
aliked = ALIKED("16rot-top1k")
ret0 = aliked('images/cathe0.jpg')
visualize_images("keypoints", ret0.visualized_img)
